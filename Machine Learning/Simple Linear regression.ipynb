# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the datasets

# %%
dataset= pd.read_csv('Salary_Data.csv')
X= dataset.iloc[:,:-1].values
Y= dataset.iloc[:,-1].values

# %% [markdown]
# ## Splitting into training and test dataset

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## Training the SLR model on training set

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the test set results

# %%
Y_predicted = regressor.predict(X_test)

# %% [markdown]
# ## Visualising training set results

# %%
plt.scatter(X_train, Y_train, color='red')
plt.plot(X_train,regressor.predict(X_train), color='blue')
plt.title('Salary vs. Experience(in Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising test set results

# %%
plt.scatter(X_test, Y_test, color='red')
plt.plot(X_train,regressor.predict(X_train), color='blue')
plt.title('Salary vs. Experience(in Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ### Getting final SLR equation with values of constant(intercept) and coefficient

# %%
print(regressor.coef_)
print(regressor.intercept_)   #eqn is Salary = 26780.09915062818 + 9312.57512673 x Years of experience
# Out:
# [9312.57512673]
# 26780.09915062818

# %% [markdown]
# ## Making a single prediction in salary

# %%
print(regressor.predict([[13]]))           # salary of person with 13 yrs of exp.

# 13 is in double square quotes as it represents a 2D array. This is because predict() method
# always expects a 2D array
# Out:
# [147843.57579811]
